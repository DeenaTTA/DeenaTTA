# %%
x=int(input("Enter your 1st number"))
y=int(input("Enter your 2nd number"))
z=input("Enter a for addition,b for substraction,c for division,d for Multiplication & e for Square")

if z=="a": 
 a=x+y
 print (a) 
elif z=="b":
  answer = x-y
  print (answer)
elif z=="c":
  answer=x/y
  print(answer) 
elif z=="d":
  answer=x*y
  print(answer)
elif z=="e":
  answer=x**y
  print(answer)
# Out:
# ...
